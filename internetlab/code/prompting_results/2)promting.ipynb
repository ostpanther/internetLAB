# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# ...

# %%
! pip install python-dotenv

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key  = os.getenv("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")

openai.api_key = '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'

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
! pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.14.0
#     Uninstalling openai-1.14.0:
#       Successfully uninstalled openai-1.14.0
# ...

# %%
sample = """УКАЗ ПРЕЗИДЕНТА РОССИЙСКОЙ ФЕДЕРАЦИИ
О Стратегии развития информационного общества в Российской Федерации на 2017 - 2030 годы

В целях обеспечения условий для формирования в Российской Федерации общества знаний постановляю:
1. Утвердить	прилагаемую Стратегию развития информационного общества в Российской Федерации на 2017 - 2030 годы.
2.	Правительству Российской Федерации утвердить до 1 октября 2017 г. перечень показателей реализации Стратегии развития информационного общества в Российской Федерации на 2017 - 2030 годы (далее - Стратегия) и план ее реализации.
3.	Правительству Российской Федерации в 6-месячный срок:
  а)	внести изменения в документы стратегического планирования в соответствии со Стратегией;
  б)	обеспечить внесение изменений в документы стратегического планирования федеральных органов исполнительной власти в соответствии со Стратегией.
4.	Рекомендовать органам государственной власти субъектов Российской Федерации и органам местного самоуправления внести изменения в документы стратегического планирования в соответствии со Стратегией.
5.	Признать утратившей силу Стратегию развития информационного общества в Российской Федерации, утвержденную Президентом Российской Федерации 7 февраля 2008 г. № Пр-212.
6.	Настоящий Указ вступает в силу со дня его подписания.
В.Путин
Москва, Кремль 9 мая 2017 года №203"""

prompt = f"""
You will be provided with text delimited by triple backticks.

You have got a Russian legal text. Your goal is to find named entities and
provide them in JSON format with the following keys:
DOC, ACT, LOC, NAME

The meaning of each tag you can find bellow:
Tags:
DOC — the name of the document
ACT - a law or regulation
LOC - location
NAME - names

```{sample}```

"""
response = get_completion(prompt)
print(response)
# Out:
# {
#   "DOC": "УКАЗ ПРЕЗИДЕНТА РОССИЙСКОЙ ФЕДЕРАЦИИ",
#   "ACT": "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы",
#   "LOC": [
#     "Российская Федерация",
#     "Москва",
#     "Кремль"
#   ],
#   "NAME": [
#     "В.Путин"
#   ]
# }

# %%
sample1 = """Стратегия развития информационного общества \
в Российской Федерации на 2017 - 2030 годы.
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по \
реализации внутренней и внешней политики Российской Федерации в \
сфере применения информационных и коммуникационных \
технологий, направленные на развитие информационного общества, \
формирование национальной цифровой экономики, обеспечение \
национальных интересов и реализацию стратегических национальных \
приоритетов.
2.	Правовую основу настоящей Стратегии составляют \
Конституция Российской Федерации, Федеральный закон от 28 июня \
2014 г. № 172-ФЗ "О стратегическом планировании в Российской \
Федерации", другие федеральные законы, Стратегия национальной \
безопасности Российской Федерации и Доктрина информационной \
безопасности Российской Федерации, утвержденные Президентом \
Российской Федерации, иные нормативные правовые акты \
Российской Федерации, определяющие направления применения \
информационных и коммуникационных технологий в Российской \
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при \
работе с информацией;
в)	сохранение традиционных и привычных для граждан \
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных \
ценностей и соблюдение основанных на этих ценностях \
норм поведения при использовании информационных и \
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе, \
накоплении и распространении информации о гражданах \
и организациях;
е)	обеспечение государственной защиты интересов российских \
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные \
понятия:
а)	безопасные программное обеспечение и сервис - программное \
обеспечение и сервис, сертифицированные на соответствие \
требованиям к информационной безопасности, устанавливаемым \
федеральным органом исполнительной власти, уполномоченным \
в области обеспечения безопасности, или федеральным органом \
исполнительной власти, уполномоченным в области противодействия \
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения \
информационных и коммуникационных инфраструктур на основе \
подключения к информационно-телекоммуникационной сети \
"Интернет" (далее - сеть "Интернет") промышленных устройств, \
оборудования, датчиков, сенсоров, систем управления \
технологическими процессами, а также интеграции данных \
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети, \
соединяющей вещи (физические предметы), оснащенные \
встроенными информационными технологиями для взаимодействия \
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором \
информация и уровень ее применения и доступности кардинальным \
образом влияют на экономические и социокультурные условия жизни \
граждан;
д)	информационное пространство - совокупность \
информационных ресурсов, созданных субъектами информационной \
сферы, средств взаимодействия таких субъектов, их информационных \
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность \
размещенных на территории Российской Федерации государственных \
информационных систем, программно-аппаратных средств и сетей \
связи, обеспечивающих при оказании услуг и осуществлении \
функций в электронной форме взаимодействие органов \
государственной власти Российской Федерации, органов местного \
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской \
Федерации (далее - критическая информационная инфраструктура) - \
совокупность объектов критической информационной \
инфраструктуры, а также сетей электросвязи, используемых для \
организации взаимодействия объектов критической информационной \
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная \
государственная информационная система, представляющая собой \
совокупность документов и сведений в электронной форме (объекты \
исторического, научного и культурного достояния народов \
Российской Федерации), доступ к которым предоставляется \
с использованием сети "Интернет"; \
и)	облачные вычисления - информационно-технологическая \
модель обеспечения повсеместного и удобного доступа с \
использованием сети "Интернет" к общему набору конфигурируемых \
вычислительных ресурсов ("облаку"), устройствам хранения данных, \
приложениям и сервисам, которые могут быть оперативно \
предоставлены и освобождены от нагрузки с минимальными \
эксплуатационными затратами или практически без участия \
провайдера;
к)	обработка больших объемов данных - совокупность подходов, \
инструментов и методов автоматической обработки \
структурированной и неструктурированной информации, \
поступающей из большого количества различных, в том числе \
разрозненных или слабосвязанных, источников информации, \
в объемах, которые невозможно обработать вручную за разумное \
время;
л)	общество знаний - общество, в котором преобладающее \
значение для развития гражданина, экономики и государства имеют \
получение, сохранение, производство и распространение достоверной \
информации с учетом стратегических национальных приоритетов \
Российской Федерации;
м)	объекты критической информационной инфраструктуры - \
информационные системы и информационно-телекоммуникационные \
сети государственных органов, а также информационные системы, \
информационно-телекоммуникационные сети и автоматизированные \
системы управления технологическими процессами, \
функционирующие в оборонной промышленности, в сфере \
здравоохранения, транспорта, связи, в кредитно-финансовой сфере, \
энергетике, топливной, атомной, ракетно-космической, \
горнодобывающей, металлургической и химической \
промышленности;
н)	сети связи нового поколения - технологические системы, \
предназначенные для подключения к сети "Интернет" пятого \
поколения в целях использования в устройствах интернета вещей и \
индустриального интернета;
о)	технологически независимые программное обеспечение и \
сервис - программное обеспечение и сервис, которые могут быть \
использованы на всей территории Российской Федерации, \
обеспечены гарантийной и технической поддержкой российских \
организаций, не имеют принудительного обновления и управления \
из-за рубежа, модернизация которых осуществляется российскими \
организациями на территории Российской Федерации и которые \
не осуществляют несанкционированную передачу информации, \
в том числе технологической;
п)	туманные вычисления - информационно-технологическая \
модель системного уровня для расширения облачных функций \
хранения, вычисления и сетевого взаимодействия, в которой \
обработка данных осуществляется на конечном оборудовании \
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое) \
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой \
ключевым фактором производства являются данные в цифровом виде, \
обработка больших объемов и использование результатов анализа \
которых по сравнению с традиционными формами хозяйствования \
позволяют существенно повысить эффективность различных видов \
производства, технологий, оборудования, хранения, продажи, \
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций, \
обеспечивающее постоянное взаимодействие принадлежащих \
им технологических платформ, прикладных интернет-сервисов, \
аналитических систем, информационных систем органов \
государственной власти Российской Федерации, организаций \
и граждан."""

prompt = f"""
You will be provided with text delimited by triple backticks.

You have got a Russian legal text which topic is 'Information Society Development Strategy
in the Russian Federation for 2017-2030'. Your goal is to find named entities and
provide them in JSON format with the following keys:
DOC, ACT, LOC, NAME, MAIN

The meaning of each tag you can find bellow:
Tags:
DOC — the name of the document
ACT - a law or regulation
LOC - location
NAME - names
MAIN - key ideas of the document

```{sample1}```

"""
response = get_completion(prompt)
print(response)
# Out:
# {
#   "entities": [
#     {
#       "DOC": "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы",
#       "ACT": "Федеральный закон от 28 июня 2014 г. № 172-ФЗ",
#       "LOC": "Российская Федерация",
#       "NAME": "Президент Российской Федерации",
#       "MAIN": "информационное общество, национальная цифровая экономика, национальные интересы, стратегические национальные приоритеты, информационная безопасность, облачные вычисления, цифровая экономика, экосистема цифровой экономики"
#     }
#   ]
# }

# %%
sample2 = """Стратегия развития информационного общества
в Российской Федерации на 2017 - 2030 годы
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по
реализации внутренней и внешней политики Российской Федерации в
сфере применения информационных и коммуникационных
технологий, направленные на развитие информационного общества,
формирование национальной цифровой экономики, обеспечение
национальных интересов и реализацию стратегических национальных
приоритетов.
2.	Правовую основу настоящей Стратегии составляют
Конституция Российской Федерации, Федеральный закон от 28 июня
2014 г. № 172-ФЗ "О стратегическом планировании в Российской
Федерации", другие федеральные законы, Стратегия национальной
безопасности Российской Федерации и Доктрина информационной
безопасности Российской Федерации, утвержденные Президентом
Российской Федерации, иные нормативные правовые акты
Российской Федерации, определяющие направления применения
информационных и коммуникационных технологий в Российской
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при
работе с информацией;
в)	сохранение традиционных и привычных для граждан
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных
ценностей и соблюдение основанных на этих ценностях
норм поведения при использовании информационных и
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе,
накоплении и распространении информации о гражданах
и организациях;
е)	обеспечение государственной защиты интересов российских
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные
понятия:
а)	безопасные программное обеспечение и сервис - программное
обеспечение и сервис, сертифицированные на соответствие
требованиям к информационной безопасности, устанавливаемым
федеральным органом исполнительной власти, уполномоченным
в области обеспечения безопасности, или федеральным органом
исполнительной власти, уполномоченным в области противодействия
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения
информационных и коммуникационных инфраструктур на основе
подключения к информационно-телекоммуникационной сети
"Интернет" (далее - сеть "Интернет") промышленных устройств,
оборудования, датчиков, сенсоров, систем управления
технологическими процессами, а также интеграции данных
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети,
соединяющей вещи (физические предметы), оснащенные
встроенными информационными технологиями для взаимодействия
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором
информация и уровень ее применения и доступности кардинальным
образом влияют на экономические и социокультурные условия жизни
граждан;
д)	информационное пространство - совокупность
информационных ресурсов, созданных субъектами информационной
сферы, средств взаимодействия таких субъектов, их информационных
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность
размещенных на территории Российской Федерации государственных
информационных систем, программно-аппаратных средств и сетей
связи, обеспечивающих при оказании услуг и осуществлении
функций в электронной форме взаимодействие органов
государственной власти Российской Федерации, органов местного
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской
Федерации (далее - критическая информационная инфраструктура) -
совокупность объектов критической информационной
инфраструктуры, а также сетей электросвязи, используемых для
организации взаимодействия объектов критической информационной
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная
государственная информационная система, представляющая собой
совокупность документов и сведений в электронной форме (объекты
исторического, научного и культурного достояния народов
Российской Федерации), доступ к которым предоставляется
с использованием сети "Интернет";
и)	облачные вычисления - информационно-технологическая
модель обеспечения повсеместного и удобного доступа с
использованием сети "Интернет" к общему набору конфигурируемых
вычислительных ресурсов ("облаку"), устройствам хранения данных,
приложениям и сервисам, которые могут быть оперативно
предоставлены и освобождены от нагрузки с минимальными
эксплуатационными затратами или практически без участия
провайдера;
к)	обработка больших объемов данных - совокупность подходов,
инструментов и методов автоматической обработки
структурированной и неструктурированной информации,
поступающей из большого количества различных, в том числе
разрозненных или слабосвязанных, источников информации,
в объемах, которые невозможно обработать вручную за разумное
время;
л)	общество знаний - общество, в котором преобладающее
значение для развития гражданина, экономики и государства имеют
получение, сохранение, производство и распространение достоверной
информации с учетом стратегических национальных приоритетов
Российской Федерации;
м)	объекты критической информационной инфраструктуры -
информационные системы и информационно-телекоммуникационные
сети государственных органов, а также информационные системы,
информационно-телекоммуникационные сети и автоматизированные
системы управления технологическими процессами,
функционирующие в оборонной промышленности, в сфере
здравоохранения, транспорта, связи, в кредитно-финансовой сфере,
энергетике, топливной, атомной, ракетно-космической,
горнодобывающей, металлургической и химической
промышленности;
н)	сети связи нового поколения - технологические системы,
предназначенные для подключения к сети "Интернет" пятого
поколения в целях использования в устройствах интернета вещей и
индустриального интернета;
о)	технологически независимые программное обеспечение и
сервис - программное обеспечение и сервис, которые могут быть
использованы на всей территории Российской Федерации,
обеспечены гарантийной и технической поддержкой российских
организаций, не имеют принудительного обновления и управления
из-за рубежа, модернизация которых осуществляется российскими
организациями на территории Российской Федерации и которые
не осуществляют несанкционированную передачу информации,
в том числе технологической;
п)	туманные вычисления - информационно-технологическая
модель системного уровня для расширения облачных функций
хранения, вычисления и сетевого взаимодействия, в которой
обработка данных осуществляется на конечном оборудовании
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое)
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой
ключевым фактором производства являются данные в цифровом виде,
обработка больших объемов и использование результатов анализа
которых по сравнению с традиционными формами хозяйствования
позволяют существенно повысить эффективность различных видов
производства, технологий, оборудования, хранения, продажи,
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций,
обеспечивающее постоянное взаимодействие принадлежащих
им технологических платформ, прикладных интернет-сервисов,
аналитических систем, информационных систем органов
государственной власти Российской Федерации, организаций
и граждан."""

prompt = f"""
You will be provided with text delimited by triple backticks.

You have got a Russian legal text which topic is 'Information Society Development Strategy
in the Russian Federation for 2017-2030'. Your goal is to find all terms and
provide them in JSON format with the following key:

- TERM (term name)

If there is a term inside the term annotation you have to privide it with
nested JSON

```{sample2}```

"""
response = get_completion(prompt)
print(response)
# Out:
# ```json
# {
#     "TERM": "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы",
#     "Общие положения": {
#         "цели": "определяет цели, задачи и меры по реализации внутренней и внешней политики Российской Федерации в сфере применения информационных и коммуникационных технологий, направленные на развитие информационного общества, формирование национальной цифровой экономики, обеспечение национальных интересов и реализацию стратегических национальных приоритетов"
#     },
#     "Правовая основа": {
#         "Конституция Российской Федерации": {},
#         "Федеральный закон от 28 июня 2014 г. № 172-ФЗ": {},
#         "Стратегия национальной безопасности Российской Федерации": {},
#         "Доктрина информационной безопасности Российской Федерации": {}
#     },
#     "Основные принципы": {
#         "а": "обеспечение прав граждан на доступ к информации",
# ...

# %%
sample3 = """Стратегия развития информационного общества
в Российской Федерации на 2017 - 2030 годы
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по
реализации внутренней и внешней политики Российской Федерации в
сфере применения информационных и коммуникационных
технологий, направленные на развитие информационного общества,
формирование национальной цифровой экономики, обеспечение
национальных интересов и реализацию стратегических национальных
приоритетов.
2.	Правовую основу настоящей Стратегии составляют
Конституция Российской Федерации, Федеральный закон от 28 июня
2014 г. № 172-ФЗ "О стратегическом планировании в Российской
Федерации", другие федеральные законы, Стратегия национальной
безопасности Российской Федерации и Доктрина информационной
безопасности Российской Федерации, утвержденные Президентом
Российской Федерации, иные нормативные правовые акты
Российской Федерации, определяющие направления применения
информационных и коммуникационных технологий в Российской
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при
работе с информацией;
в)	сохранение традиционных и привычных для граждан
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных
ценностей и соблюдение основанных на этих ценностях
норм поведения при использовании информационных и
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе,
накоплении и распространении информации о гражданах
и организациях;
е)	обеспечение государственной защиты интересов российских
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные
понятия:
а)	безопасные программное обеспечение и сервис - программное
обеспечение и сервис, сертифицированные на соответствие
требованиям к информационной безопасности, устанавливаемым
федеральным органом исполнительной власти, уполномоченным
в области обеспечения безопасности, или федеральным органом
исполнительной власти, уполномоченным в области противодействия
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения
информационных и коммуникационных инфраструктур на основе
подключения к информационно-телекоммуникационной сети
"Интернет" (далее - сеть "Интернет") промышленных устройств,
оборудования, датчиков, сенсоров, систем управления
технологическими процессами, а также интеграции данных
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети,
соединяющей вещи (физические предметы), оснащенные
встроенными информационными технологиями для взаимодействия
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором
информация и уровень ее применения и доступности кардинальным
образом влияют на экономические и социокультурные условия жизни
граждан;
д)	информационное пространство - совокупность
информационных ресурсов, созданных субъектами информационной
сферы, средств взаимодействия таких субъектов, их информационных
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность
размещенных на территории Российской Федерации государственных
информационных систем, программно-аппаратных средств и сетей
связи, обеспечивающих при оказании услуг и осуществлении
функций в электронной форме взаимодействие органов
государственной власти Российской Федерации, органов местного
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской
Федерации (далее - критическая информационная инфраструктура) -
совокупность объектов критической информационной
инфраструктуры, а также сетей электросвязи, используемых для
организации взаимодействия объектов критической информационной
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная
государственная информационная система, представляющая собой
совокупность документов и сведений в электронной форме (объекты
исторического, научного и культурного достояния народов
Российской Федерации), доступ к которым предоставляется
с использованием сети "Интернет";
и)	облачные вычисления - информационно-технологическая
модель обеспечения повсеместного и удобного доступа с
использованием сети "Интернет" к общему набору конфигурируемых
вычислительных ресурсов ("облаку"), устройствам хранения данных,
приложениям и сервисам, которые могут быть оперативно
предоставлены и освобождены от нагрузки с минимальными
эксплуатационными затратами или практически без участия
провайдера;
к)	обработка больших объемов данных - совокупность подходов,
инструментов и методов автоматической обработки
структурированной и неструктурированной информации,
поступающей из большого количества различных, в том числе
разрозненных или слабосвязанных, источников информации,
в объемах, которые невозможно обработать вручную за разумное
время;
л)	общество знаний - общество, в котором преобладающее
значение для развития гражданина, экономики и государства имеют
получение, сохранение, производство и распространение достоверной
информации с учетом стратегических национальных приоритетов
Российской Федерации;
м)	объекты критической информационной инфраструктуры -
информационные системы и информационно-телекоммуникационные
сети государственных органов, а также информационные системы,
информационно-телекоммуникационные сети и автоматизированные
системы управления технологическими процессами,
функционирующие в оборонной промышленности, в сфере
здравоохранения, транспорта, связи, в кредитно-финансовой сфере,
энергетике, топливной, атомной, ракетно-космической,
горнодобывающей, металлургической и химической
промышленности;
н)	сети связи нового поколения - технологические системы,
предназначенные для подключения к сети "Интернет" пятого
поколения в целях использования в устройствах интернета вещей и
индустриального интернета;
о)	технологически независимые программное обеспечение и
сервис - программное обеспечение и сервис, которые могут быть
использованы на всей территории Российской Федерации,
обеспечены гарантийной и технической поддержкой российских
организаций, не имеют принудительного обновления и управления
из-за рубежа, модернизация которых осуществляется российскими
организациями на территории Российской Федерации и которые
не осуществляют несанкционированную передачу информации,
в том числе технологической;
п)	туманные вычисления - информационно-технологическая
модель системного уровня для расширения облачных функций
хранения, вычисления и сетевого взаимодействия, в которой
обработка данных осуществляется на конечном оборудовании
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое)
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой
ключевым фактором производства являются данные в цифровом виде,
обработка больших объемов и использование результатов анализа
которых по сравнению с традиционными формами хозяйствования
позволяют существенно повысить эффективность различных видов
производства, технологий, оборудования, хранения, продажи,
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций,
обеспечивающее постоянное взаимодействие принадлежащих
им технологических платформ, прикладных интернет-сервисов,
аналитических систем, информационных систем органов
государственной власти Российской Федерации, организаций
и граждан."""

prompt = f"""

Your previous response was almost correct, but you didnt cover all terms.

You will be provided with text delimited by triple backticks.

You have got a Russian legal text which topic is 'Information Society Development Strategy
in the Russian Federation for 2017-2030'. Your goal is to find all terms and subterms which have to be nested and
provide them in JSON format with the following key:

- DOC (doc name)
- TERM (term name)

If there is a term inside the term annotation you have to privide it with
nested summarized annotation(max 10 words) JSON

```{sample3}```

The correct output should look something like this:

{{
    DOC: Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы,
    TERM: {{Общие положения: [
                                  {{цели, задачи и меры: развитие информационного общества,формирование национальной цифровой экономики, обеспечение национальных интересов ...}},
                                  {{Правовая основа: Конституция Российской Федерации, Федеральный закон от 28 июня 2014 г. № 172-ФЗ 'О стратегическом планировании в Российской Федерации'...}},
                                  {{Основные принципы: {{
                                                          а: обеспечение прав граждан на доступ к информации,
                                                          б: обеспечение свободы выбора средств получения знаний при работе с информацией,
                                                          ...: ...}},
                                  {{Основные понятия: {{
                                  безопасные программное обеспечение и сервис: сертифицированные на соответствие требованиям к информационной безопасности,
                                  индустриальный интернет: концепция построения информационных и коммуникационных инфраструктур на основе подключения к информационно-телекоммуникационной сети 'Интернет',
                                  ...: ...}}
                                  ]

            }}
}}'


"""
response = get_completion(prompt)
print(response)
# Out:
# {
#     "DOC": "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы",
#     "TERM": {
#         "Общие положения": [
#             {
#                 "цели, задачи и меры": "развитие информационного общества, формирование национальной цифровой экономики, обеспечение национальных интересов и реализацию стратегических национальных приоритетов"
#             },
#             {
#                 "Правовая основа": "Конституция Российской Федерации, Федеральный закон от 28 июня 2014 г. № 172-ФЗ 'О стратегическом планировании в Российской Федерации', другие федеральные законы, Стратегия национальной безопасности Российской Федерации и Доктрина информационной безопасности Российской Федерации, утвержденные Президентом Российской Федерации, иные нормативные правовые акты Российской Федерации, определяющие направления применения информационных и коммуникационных технологий в Российской Федерации"
#             },
#             {
# ...

# %%
text = f"""
The site stores audiobooks with meta information linked to them. \
One audiobook consists of several files. \
Registered users can listen to audiobooks, interrupting listening at any time, with the ability to play from the same location. \
The user can listen to several books.
"""


prompt = f"""
Laboratory work on SQL and NoSQL classes:

First assigmnet:

Build an ER-diagram for 'the audiobook reader service'.
You have to describe all tables you create and all relationship between tables(many to many, one to many etc.)).
Dont forget about Primary key and Foreign key.

Description of the laboratory work:

The site stores audiobooks with meta information linked to them.
One audiobook consists of several files.
Registered users can listen to audiobooks, interrupting listening at any time, with the ability to play from the same location.
The user can listen to several books.

The second passigmnet of laboratory work:

You have to create a fictional but syntactically correct query to the created database and
find three users who have started listening (and possibly listened to the end) to the maximum number of books.

```{text}```

"""

r = get_completion(s)
print(r)

# %%
prompt = f"""
Imagine that you are a database engineer and the customer asks you to create 'the audiobook reader service', provided with an ER-diagram. \
You have to describe all tables you create and all cardinalities between tables with Primary key and Foreign key.\

The site stores audiobooks with meta information linked to them. \
One audiobook consists of several files. \
Registered users can listen to audiobooks, interrupting listening at any time, with the ability to play from the same location. \
The user can listen to several books. \

Secondly, You have to create a syntactically correct query to the created database and \
find three users who have started listening (and possibly listened to the end) to the maximum number of books.
"""

answer = get_completion(prompt)
print(answer)
# Out:
# First, let's create the ER-diagram for the audiobook reader service:
#
# Tables:
# 1. Users
# - user_id (Primary key)
# - username
# - email
#
# 2. Audiobooks
# - audiobook_id (Primary key)
# - title
# - author
# - genre
#
# 3. Files
# - file_id (Primary key)
# - audiobook_id (Foreign key referencing Audiobooks)
# - file_name
# - file_path
#
# 4. ListeningHistory
# - history_id (Primary key)
# - user_id (Foreign key referencing Users)
# - audiobook_id (Foreign key referencing Audiobooks)
# - file_id (Foreign key referencing Files)
# - start_time
# - end_time
#
# Cardinalities:
# - Users (1) to ListeningHistory (Many)
# - Audiobooks (1) to Files (Many)
# - Users (Many) to ListeningHistory (Many)
# - Audiobooks (Many) to ListeningHistory (Many)
#
# Now, let's create a query to find three users who have started listening to the maximum number of books:
#
# ```sql
# SELECT user_id, COUNT(DISTINCT audiobook_id) AS num_books
# FROM ListeningHistory
# GROUP BY user_id
# ...

# %% [markdown]
# <h2>5</h2>

# %%
first_part_of_stratagy = """Стратегия развития информационного общества \
в Российской Федерации на 2017 - 2030 годы.
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по \
реализации внутренней и внешней политики Российской Федерации в \
сфере применения информационных и коммуникационных \
технологий, направленные на развитие информационного общества, \
формирование национальной цифровой экономики, обеспечение \
национальных интересов и реализацию стратегических национальных \
приоритетов.
2.	Правовую основу настоящей Стратегии составляют \
Конституция Российской Федерации, Федеральный закон от 28 июня \
2014 г. № 172-ФЗ "О стратегическом планировании в Российской \
Федерации", другие федеральные законы, Стратегия национальной \
безопасности Российской Федерации и Доктрина информационной \
безопасности Российской Федерации, утвержденные Президентом \
Российской Федерации, иные нормативные правовые акты \
Российской Федерации, определяющие направления применения \
информационных и коммуникационных технологий в Российской \
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при \
работе с информацией;
в)	сохранение традиционных и привычных для граждан \
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных \
ценностей и соблюдение основанных на этих ценностях \
норм поведения при использовании информационных и \
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе, \
накоплении и распространении информации о гражданах \
и организациях;
е)	обеспечение государственной защиты интересов российских \
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные \
понятия:
а)	безопасные программное обеспечение и сервис - программное \
обеспечение и сервис, сертифицированные на соответствие \
требованиям к информационной безопасности, устанавливаемым \
федеральным органом исполнительной власти, уполномоченным \
в области обеспечения безопасности, или федеральным органом \
исполнительной власти, уполномоченным в области противодействия \
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения \
информационных и коммуникационных инфраструктур на основе \
подключения к информационно-телекоммуникационной сети \
"Интернет" (далее - сеть "Интернет") промышленных устройств, \
оборудования, датчиков, сенсоров, систем управления \
технологическими процессами, а также интеграции данных \
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети, \
соединяющей вещи (физические предметы), оснащенные \
встроенными информационными технологиями для взаимодействия \
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором \
информация и уровень ее применения и доступности кардинальным \
образом влияют на экономические и социокультурные условия жизни \
граждан;
д)	информационное пространство - совокупность \
информационных ресурсов, созданных субъектами информационной \
сферы, средств взаимодействия таких субъектов, их информационных \
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность \
размещенных на территории Российской Федерации государственных \
информационных систем, программно-аппаратных средств и сетей \
связи, обеспечивающих при оказании услуг и осуществлении \
функций в электронной форме взаимодействие органов \
государственной власти Российской Федерации, органов местного \
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской \
Федерации (далее - критическая информационная инфраструктура) - \
совокупность объектов критической информационной \
инфраструктуры, а также сетей электросвязи, используемых для \
организации взаимодействия объектов критической информационной \
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная \
государственная информационная система, представляющая собой \
совокупность документов и сведений в электронной форме (объекты \
исторического, научного и культурного достояния народов \
Российской Федерации), доступ к которым предоставляется \
с использованием сети "Интернет"; \
и)	облачные вычисления - информационно-технологическая \
модель обеспечения повсеместного и удобного доступа с \
использованием сети "Интернет" к общему набору конфигурируемых \
вычислительных ресурсов ("облаку"), устройствам хранения данных, \
приложениям и сервисам, которые могут быть оперативно \
предоставлены и освобождены от нагрузки с минимальными \
эксплуатационными затратами или практически без участия \
провайдера;
к)	обработка больших объемов данных - совокупность подходов, \
инструментов и методов автоматической обработки \
структурированной и неструктурированной информации, \
поступающей из большого количества различных, в том числе \
разрозненных или слабосвязанных, источников информации, \
в объемах, которые невозможно обработать вручную за разумное \
время;
л)	общество знаний - общество, в котором преобладающее \
значение для развития гражданина, экономики и государства имеют \
получение, сохранение, производство и распространение достоверной \
информации с учетом стратегических национальных приоритетов \
Российской Федерации;
м)	объекты критической информационной инфраструктуры - \
информационные системы и информационно-телекоммуникационные \
сети государственных органов, а также информационные системы, \
информационно-телекоммуникационные сети и автоматизированные \
системы управления технологическими процессами, \
функционирующие в оборонной промышленности, в сфере \
здравоохранения, транспорта, связи, в кредитно-финансовой сфере, \
энергетике, топливной, атомной, ракетно-космической, \
горнодобывающей, металлургической и химической \
промышленности;
н)	сети связи нового поколения - технологические системы, \
предназначенные для подключения к сети "Интернет" пятого \
поколения в целях использования в устройствах интернета вещей и \
индустриального интернета;
о)	технологически независимые программное обеспечение и \
сервис - программное обеспечение и сервис, которые могут быть \
использованы на всей территории Российской Федерации, \
обеспечены гарантийной и технической поддержкой российских \
организаций, не имеют принудительного обновления и управления \
из-за рубежа, модернизация которых осуществляется российскими \
организациями на территории Российской Федерации и которые \
не осуществляют несанкционированную передачу информации, \
в том числе технологической;
п)	туманные вычисления - информационно-технологическая \
модель системного уровня для расширения облачных функций \
хранения, вычисления и сетевого взаимодействия, в которой \
обработка данных осуществляется на конечном оборудовании \
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое) \
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой \
ключевым фактором производства являются данные в цифровом виде, \
обработка больших объемов и использование результатов анализа \
которых по сравнению с традиционными формами хозяйствования \
позволяют существенно повысить эффективность различных видов \
производства, технологий, оборудования, хранения, продажи, \
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций, \
обеспечивающее постоянное взаимодействие принадлежащих \
им технологических платформ, прикладных интернет-сервисов, \
аналитических систем, информационных систем органов \
государственной власти Российской Федерации, организаций \
и граждан."""

# %% [markdown]
# <h2>6</h2>

# %%
prompt1 = f"""
You will be provided with text delimited by triple backticks.

Imagine that you are a legal data scientist and you have to find all terms in provided legal document and
provide them in neasted JSON-format with the following key:

- DOC (doc name)
- TERM (term name)

You have got a Russian legal text which topic is 'Information Society Development Strategy
in the Russian Federation for 2017-2030'. Notice that line break of an unfinished semantic sentence indicated by a backslash symbol.

If there is a term inside the term annotation you have to privide it with
nested JSON and give a little annotation (max 10 words)

```{first_part_of_stratagy}```

"""
first_part_of_stratagy_response = get_completion(prompt1)
print(first_part_of_stratagy_response)
# Out:
# {
#   "DOC": "Information Society Development Strategy in the Russian Federation for 2017-2030",
#   "TERM": {
#     "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы": {},
#     "Общие положения": {},
#     "Настоящая Стратегия": {},
#     "цели, задачи и меры": {},
#     "внутренней и внешней политики": {},
#     "Российской Федерации": {},
#     "информационных и коммуникационных технологий": {},
#     "информационного общества": {},
#     "национальной цифровой экономики": {},
#     "национальных интересов": {},
#     "стратегических национальных приоритетов": {},
#     "Правовую основу": {},
#     "Конституция Российской Федерации": {},
#     "Федеральный закон от 28 июня 2014 г. № 172-ФЗ": {},
#     "стратегическом планировании в Российской Федерации": {},
#     "Стратегия национальной безопасности Российской Федерации": {},
#     "Доктрина информационной безопасности Российской Федерации": {},
# ...

# %% [markdown]
# <h2>7</h2>

# %%
first_part_of_stratagy = """Стратегия развития информационного общества \
в Российской Федерации на 2017 - 2030 годы.
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по \
реализации внутренней и внешней политики Российской Федерации в \
сфере применения информационных и коммуникационных \
технологий, направленные на развитие информационного общества, \
формирование национальной цифровой экономики, обеспечение \
национальных интересов и реализацию стратегических национальных \
приоритетов.
2.	Правовую основу настоящей Стратегии составляют \
Конституция Российской Федерации, Федеральный закон от 28 июня \
2014 г. № 172-ФЗ "О стратегическом планировании в Российской \
Федерации", другие федеральные законы, Стратегия национальной \
безопасности Российской Федерации и Доктрина информационной \
безопасности Российской Федерации, утвержденные Президентом \
Российской Федерации, иные нормативные правовые акты \
Российской Федерации, определяющие направления применения \
информационных и коммуникационных технологий в Российской \
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при \
работе с информацией;
в)	сохранение традиционных и привычных для граждан \
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных \
ценностей и соблюдение основанных на этих ценностях \
норм поведения при использовании информационных и \
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе, \
накоплении и распространении информации о гражданах \
и организациях;
е)	обеспечение государственной защиты интересов российских \
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные \
понятия:
а)	безопасные программное обеспечение и сервис - программное \
обеспечение и сервис, сертифицированные на соответствие \
требованиям к информационной безопасности, устанавливаемым \
федеральным органом исполнительной власти, уполномоченным \
в области обеспечения безопасности, или федеральным органом \
исполнительной власти, уполномоченным в области противодействия \
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения \
информационных и коммуникационных инфраструктур на основе \
подключения к информационно-телекоммуникационной сети \
"Интернет" (далее - сеть "Интернет") промышленных устройств, \
оборудования, датчиков, сенсоров, систем управления \
технологическими процессами, а также интеграции данных \
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети, \
соединяющей вещи (физические предметы), оснащенные \
встроенными информационными технологиями для взаимодействия \
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором \
информация и уровень ее применения и доступности кардинальным \
образом влияют на экономические и социокультурные условия жизни \
граждан;
д)	информационное пространство - совокупность \
информационных ресурсов, созданных субъектами информационной \
сферы, средств взаимодействия таких субъектов, их информационных \
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность \
размещенных на территории Российской Федерации государственных \
информационных систем, программно-аппаратных средств и сетей \
связи, обеспечивающих при оказании услуг и осуществлении \
функций в электронной форме взаимодействие органов \
государственной власти Российской Федерации, органов местного \
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской \
Федерации (далее - критическая информационная инфраструктура) - \
совокупность объектов критической информационной \
инфраструктуры, а также сетей электросвязи, используемых для \
организации взаимодействия объектов критической информационной \
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная \
государственная информационная система, представляющая собой \
совокупность документов и сведений в электронной форме (объекты \
исторического, научного и культурного достояния народов \
Российской Федерации), доступ к которым предоставляется \
с использованием сети "Интернет"; \
и)	облачные вычисления - информационно-технологическая \
модель обеспечения повсеместного и удобного доступа с \
использованием сети "Интернет" к общему набору конфигурируемых \
вычислительных ресурсов ("облаку"), устройствам хранения данных, \
приложениям и сервисам, которые могут быть оперативно \
предоставлены и освобождены от нагрузки с минимальными \
эксплуатационными затратами или практически без участия \
провайдера;
к)	обработка больших объемов данных - совокупность подходов, \
инструментов и методов автоматической обработки \
структурированной и неструктурированной информации, \
поступающей из большого количества различных, в том числе \
разрозненных или слабосвязанных, источников информации, \
в объемах, которые невозможно обработать вручную за разумное \
время;
л)	общество знаний - общество, в котором преобладающее \
значение для развития гражданина, экономики и государства имеют \
получение, сохранение, производство и распространение достоверной \
информации с учетом стратегических национальных приоритетов \
Российской Федерации;
м)	объекты критической информационной инфраструктуры - \
информационные системы и информационно-телекоммуникационные \
сети государственных органов, а также информационные системы, \
информационно-телекоммуникационные сети и автоматизированные \
системы управления технологическими процессами, \
функционирующие в оборонной промышленности, в сфере \
здравоохранения, транспорта, связи, в кредитно-финансовой сфере, \
энергетике, топливной, атомной, ракетно-космической, \
горнодобывающей, металлургической и химической \
промышленности;
н)	сети связи нового поколения - технологические системы, \
предназначенные для подключения к сети "Интернет" пятого \
поколения в целях использования в устройствах интернета вещей и \
индустриального интернета;
о)	технологически независимые программное обеспечение и \
сервис - программное обеспечение и сервис, которые могут быть \
использованы на всей территории Российской Федерации, \
обеспечены гарантийной и технической поддержкой российских \
организаций, не имеют принудительного обновления и управления \
из-за рубежа, модернизация которых осуществляется российскими \
организациями на территории Российской Федерации и которые \
не осуществляют несанкционированную передачу информации, \
в том числе технологической;
п)	туманные вычисления - информационно-технологическая \
модель системного уровня для расширения облачных функций \
хранения, вычисления и сетевого взаимодействия, в которой \
обработка данных осуществляется на конечном оборудовании \
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое) \
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой \
ключевым фактором производства являются данные в цифровом виде, \
обработка больших объемов и использование результатов анализа \
которых по сравнению с традиционными формами хозяйствования \
позволяют существенно повысить эффективность различных видов \
производства, технологий, оборудования, хранения, продажи, \
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций, \
обеспечивающее постоянное взаимодействие принадлежащих \
им технологических платформ, прикладных интернет-сервисов, \
аналитических систем, информационных систем органов \
государственной власти Российской Федерации, организаций \
и граждан."""

prompt = f"""
You will be provided with text delimited by triple backticks.

You have got a Russian legal text which topic is 'Information Society Development Strategy
in the Russian Federation for 2017-2030'. Your goal is to find all terms and
provide them in JSON format with the following key:

- DOC (document name)
- TERM (term name)

If there is a term inside the term annotation you have to privide it with
nested JSON

```{first_part_of_stratagy}```

"""
response6 = get_completion(prompt)
print(response6)
# Out:
# ```json
# [
#     {
#         "DOC": "Information Society Development Strategy in the Russian Federation for 2017-2030",
#         "TERM": "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы",
#         "nested_terms": [
#             {
#                 "TERM": "Общие положения",
#                 "nested_terms": [
#                     {
#                         "TERM": "цели, задачи и меры по реализации внутренней и внешней политики Российской Федерации в сфере применения информационных и коммуникационных технологий"
#                     },
#                     {
#                         "TERM": "правовую основу",
#                         "nested_terms": [
#                             {
#                                 "TERM": "Конституция Российской Федерации"
#                             },
#                             {
# ...

# %% [markdown]
# <h2>8</h2>

# %%
first_part_of_stratagy = """Стратегия развития информационного общества \
в Российской Федерации на 2017 - 2030 годы.
I.	Общие положения
1.	Настоящая Стратегия определяет цели, задачи и меры по \
реализации внутренней и внешней политики Российской Федерации в \
сфере применения информационных и коммуникационных \
технологий, направленные на развитие информационного общества, \
формирование национальной цифровой экономики, обеспечение \
национальных интересов и реализацию стратегических национальных \
приоритетов.
2.	Правовую основу настоящей Стратегии составляют \
Конституция Российской Федерации, Федеральный закон от 28 июня \
2014 г. № 172-ФЗ "О стратегическом планировании в Российской \
Федерации", другие федеральные законы, Стратегия национальной \
безопасности Российской Федерации и Доктрина информационной \
безопасности Российской Федерации, утвержденные Президентом \
Российской Федерации, иные нормативные правовые акты \
Российской Федерации, определяющие направления применения \
информационных и коммуникационных технологий в Российской \
Федерации.
3.	Основными принципами настоящей Стратегии являются:
а)	обеспечение прав граждан на доступ к информации;
б)	обеспечение свободы выбора средств получения знаний при \
работе с информацией;
в)	сохранение традиционных и привычных для граждан \
(отличных от цифровых) форм получения товаров и услуг;
г)	приоритет традиционных российских духовно-нравственных \
ценностей и соблюдение основанных на этих ценностях \
норм поведения при использовании информационных и \
коммуникационных технологий;
д)	обеспечение законности и разумной достаточности при сборе, \
накоплении и распространении информации о гражданах \
и организациях;
е)	обеспечение государственной защиты интересов российских \
граждан в информационной сфере.
4.	В настоящей Стратегии используются следующие основные \
понятия:
а)	безопасные программное обеспечение и сервис - программное \
обеспечение и сервис, сертифицированные на соответствие \
требованиям к информационной безопасности, устанавливаемым \
федеральным органом исполнительной власти, уполномоченным \
в области обеспечения безопасности, или федеральным органом \
исполнительной власти, уполномоченным в области противодействия \
техническим разведкам и технической защиты информации;
б)	индустриальный интернет - концепция построения \
информационных и коммуникационных инфраструктур на основе \
подключения к информационно-телекоммуникационной сети \
"Интернет" (далее - сеть "Интернет") промышленных устройств, \
оборудования, датчиков, сенсоров, систем управления \
технологическими процессами, а также интеграции данных \
программно-аппаратных средств между собой без участия человека;
в)	интернет вещей - концепция вычислительной сети, \
соединяющей вещи (физические предметы), оснащенные \
встроенными информационными технологиями для взаимодействия \
друг с другом или с внешней средой без участия человека;
г)	информационное общество - общество, в котором \
информация и уровень ее применения и доступности кардинальным \
образом влияют на экономические и социокультурные условия жизни \
граждан;
д)	информационное пространство - совокупность \
информационных ресурсов, созданных субъектами информационной \
сферы, средств взаимодействия таких субъектов, их информационных \
систем и необходимой информационной инфраструктуры;
е)	инфраструктура электронного правительства - совокупность \
размещенных на территории Российской Федерации государственных \
информационных систем, программно-аппаратных средств и сетей \
связи, обеспечивающих при оказании услуг и осуществлении \
функций в электронной форме взаимодействие органов \
государственной власти Российской Федерации, органов местного \
самоуправления, граждан и юридических лиц;
ж)	критическая информационная инфраструктура Российской \
Федерации (далее - критическая информационная инфраструктура) - \
совокупность объектов критической информационной \
инфраструктуры, а также сетей электросвязи, используемых для \
организации взаимодействия объектов критической информационной \
инфраструктуры между собой;
з)	Национальная электронная библиотека - федеральная \
государственная информационная система, представляющая собой \
совокупность документов и сведений в электронной форме (объекты \
исторического, научного и культурного достояния народов \
Российской Федерации), доступ к которым предоставляется \
с использованием сети "Интернет"; \
и)	облачные вычисления - информационно-технологическая \
модель обеспечения повсеместного и удобного доступа с \
использованием сети "Интернет" к общему набору конфигурируемых \
вычислительных ресурсов ("облаку"), устройствам хранения данных, \
приложениям и сервисам, которые могут быть оперативно \
предоставлены и освобождены от нагрузки с минимальными \
эксплуатационными затратами или практически без участия \
провайдера;
к)	обработка больших объемов данных - совокупность подходов, \
инструментов и методов автоматической обработки \
структурированной и неструктурированной информации, \
поступающей из большого количества различных, в том числе \
разрозненных или слабосвязанных, источников информации, \
в объемах, которые невозможно обработать вручную за разумное \
время;
л)	общество знаний - общество, в котором преобладающее \
значение для развития гражданина, экономики и государства имеют \
получение, сохранение, производство и распространение достоверной \
информации с учетом стратегических национальных приоритетов \
Российской Федерации;
м)	объекты критической информационной инфраструктуры - \
информационные системы и информационно-телекоммуникационные \
сети государственных органов, а также информационные системы, \
информационно-телекоммуникационные сети и автоматизированные \
системы управления технологическими процессами, \
функционирующие в оборонной промышленности, в сфере \
здравоохранения, транспорта, связи, в кредитно-финансовой сфере, \
энергетике, топливной, атомной, ракетно-космической, \
горнодобывающей, металлургической и химической \
промышленности;
н)	сети связи нового поколения - технологические системы, \
предназначенные для подключения к сети "Интернет" пятого \
поколения в целях использования в устройствах интернета вещей и \
индустриального интернета;
о)	технологически независимые программное обеспечение и \
сервис - программное обеспечение и сервис, которые могут быть \
использованы на всей территории Российской Федерации, \
обеспечены гарантийной и технической поддержкой российских \
организаций, не имеют принудительного обновления и управления \
из-за рубежа, модернизация которых осуществляется российскими \
организациями на территории Российской Федерации и которые \
не осуществляют несанкционированную передачу информации, \
в том числе технологической;
п)	туманные вычисления - информационно-технологическая \
модель системного уровня для расширения облачных функций \
хранения, вычисления и сетевого взаимодействия, в которой \
обработка данных осуществляется на конечном оборудовании \
(компьютеры, мобильные устройства, датчики, смарт-узлы и другое) \
в сети, а не в "облаке";
р)	цифровая экономика - хозяйственная деятельность, в которой \
ключевым фактором производства являются данные в цифровом виде, \
обработка больших объемов и использование результатов анализа \
которых по сравнению с традиционными формами хозяйствования \
позволяют существенно повысить эффективность различных видов \
производства, технологий, оборудования, хранения, продажи, \
доставки товаров и услуг;
с)	экосистема цифровой экономики - партнерство организаций, \
обеспечивающее постоянное взаимодействие принадлежащих \
им технологических платформ, прикладных интернет-сервисов, \
аналитических систем, информационных систем органов \
государственной власти Российской Федерации, организаций \
и граждан."""

prompt = f"""
You will be provided with text delimited by triple backticks.

You have a Russian legal text with title 'Стратегия развития информационного общества
в Российской Федерации на 2017 - 2030 годы'. Your goal is to find all terms and
provide them in JSON format.

The keys must be logically correct in order to search through a JSON document in the future.

If there is a term inside the term annotation you have to privide it with
nested JSON

```{first_part_of_stratagy}```

"""
response7 = get_completion(prompt)
print(response7)
# Out:
# {
#     "terms": {
#         "Стратегия развития информационного общества в Российской Федерации на 2017 - 2030 годы": {},
#         "Общие положения": {},
#         "Настоящая Стратегия": {},
#         "цели": {},
#         "задачи": {},
#         "меры": {},
#         "внутренняя политика": {},
#         "внешняя политика": {},
#         "Российская Федерация": {},
#         "информационные технологии": {},
#         "коммуникационные технологии": {},
#         "информационное общество": {},
#         "цифровая экономика": {},
#         "национальные интересы": {},
#         "стратегические национальные приоритеты": {},
#         "Правовая основа": {},
#         "Конституция Российской Федерации": {},
#         "Федеральный закон от 28 июня 2014 г. № 172-ФЗ": {},
#         "стратегическое планирование": {},
#         "Стратегия национальной безопасности Российской Федерации": {},
#         "Доктрина информационной безопасности Российской Федерации": {},
# ...
